# %%
# import the necessary libraries
import numpy as np
import pandas as pd

# import libraries for visuals

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load and read data file
df = pd.read_csv(r"C:\Users\Official O\Desktop\DATA ANALYTICS FELLOWSHIP\FINAL PROJECTS\DAFI Project\Python Projects\storess.csv")
df
# Out:
#      Store_Id  Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0           1        1659             1961                   530        66490
# 1           2        1461             1752                   210        39820
# 2           3        1340             1609                   720        54010
# 3           4        1451             1748                   620        53730
# 4           5        1770             2111                   450        46620
# ..        ...         ...              ...                   ...          ...
# 891       892        1582             1910                  1080        66390
# 892       893        1387             1663                   850        82080
# 893       894        1200             1436                  1060        76440
# 894       895        1299             1560                   770        96610
# 895       896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
# view the shape of the data
df.shape
# Out:
# (896, 5)

# %%
# view info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store_Id              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
# view columns
df.columns
# Out:
# Index(['Store_Id', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
# check for missing values
df.isnull().sum()
# Out:
# Store_Id                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
#which store has biggest and lowest area
biggest_area = df[(df['Store_Area'] == df['Store_Area'].max())]
lowest_area = df[(df['Store_Area'] == df['Store_Area'].min())]

print (biggest_area)
print (lowest_area)
# Out:
#      Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 466        467        2229             2667                   660        87410
#      Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 158        159         775              932                  1090        42530

# %%
#which store has most and least Daily_Customer_Count
most_customer = df[(df['Daily_Customer_Count'] == df['Daily_Customer_Count'].max())]
least_customer = df[(df['Daily_Customer_Count'] == df['Daily_Customer_Count'].min())]

print (most_customer)
print (least_customer)
# Out:
#      Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 848        849         919             1099                  1560        73810
#     Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 39         40        1270             1516                    10        45480

# %%
#which store has most and least Items_Available
most_items = df[(df['Items_Available'] == df['Items_Available'].max())]
least_item = df[(df['Items_Available'] == df['Items_Available'].min())]

print (most_items)
print (least_item)
# Out:
#      Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 466        467        2229             2667                   660        87410
#      Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 158        159         775              932                  1090        42530

# %%
#which store has most and least Store_Sales
most_sales = df[(df['Store_Sales'] == df['Store_Sales'].max())]
least_sales = df[(df['Store_Sales'] == df['Store_Sales'].min())]

print (most_sales)
print (least_sales)
# Out:
#      Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 649        650        1989             2414                   860       116320
#     Store_Id   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 31         32        1250             1508                   990        14920

# %%
# Sort the data by store sales in descending order
sorted_data = df.sort_values('Store_Sales', ascending=False)

# Select the top 10 rows of the sorted data
top_10 = sorted_data.head(10)

# Create a bar chart using pandas
top_10.plot(kind='bar', x='Store_Id', y='Store_Sales', figsize=(10,7))
plt.xlabel('Store ID')
plt.ylabel('Store Sales')
plt.title('Top 10 Stores by Sales')
plt.show()

# %%
# Sort the data by Daily Customer Count in descending order
sorted_dc = df.sort_values('Daily_Customer_Count', ascending=False)

# Select the top 10 rows of the sorted data
top_10 = sorted_dc.head(10)

# Create a bar chart using pandas
top_10.plot(kind='bar', x='Store_Id', y='Daily_Customer_Count', figsize=(10,7))
plt.xlabel('Store ID')
plt.ylabel('Daily Customer Count')
plt.title('Top 10 Stores by Daily Customer Count')
plt.show()

# %%
# Sort the data by Items Available in descending order
sorted_ia = df.sort_values('Items_Available', ascending=False)

# Select the top 10 rows of the sorted data
top_10 = sorted_ia.head(10)

# Create a bar chart using pandas
top_10.plot(kind='bar', x='Store_Id', y='Items_Available', figsize=(10,7))
plt.xlabel('Store ID')
plt.ylabel('Items Available')
plt.title('Top 10 Stores by Items Available')
plt.show()
